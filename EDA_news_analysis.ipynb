# %%
import nltk
import bs4
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import requests
from bs4 import BeautifulSoup
import pandas as pd
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def GetText(url):
    site = requests.get(url).text #Request html object from url
    soup = BeautifulSoup(site, "html.parser") #Create BeautifulSoup object
    text ="" 
    for j in soup.find_all("p"): #Find all paragraph tags within the html page
        text += j.get_text() #Get text from each paragraph tag in document and append to 'text' variable
    return text

# %%
#Hardcode a url to summarise
Url1 ="https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMibmh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3Nwb3J0cy9ncmFuZC1uYXRpb25hbC1tdXRlZC1ldmVudC11ay1ib29rbWFrZXJzLWFtaWQtY29zdC1vZi1saXZpbmctY3Jpc2lzLTIwMjMtMDQtMTcv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1"
Url2 ="https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiZWh0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL2FmcmljYS96YW1iaWFucy1zdHJ1Z2dsZS13aXRoLWNvc3QtbGl2aW5nLWRlYnQtcmV3b3JrLWRyYWdzLTIwMjMtMDQtMTgv0gEA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1"
Url3 ="https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMidWh0dHBzOi8vd3d3LnJldXRlcnMuY29tL2J1c2luZXNzL3JldGFpbC1jb25zdW1lci90ZXNjby1ub3QtcHJvZml0ZWVyaW5nLWFtaWQtY29zdC1saXZpbmctY3Jpc2lzLXNheXMtYm9zcy0yMDIzLTA0LTEzL9IBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1"
Url4 ="https://lifehacker.com/make-these-renovations-before-retirement-if-you-plan-to-1850337333"
Url5 ="https://www.theguardian.com/money/2023/apr/13/uk-parents-how-has-the-higher-cost-of-living-affected-your-child-maintenance-payments"
Url6 ="https://www.theguardian.com/business/live/2023/apr/19/uk-inflation-report-march-cost-of-living-crisis-business-live"
Url7 ="https://www.theguardian.com/lifeandstyle/2023/apr/24/tell-us-how-us-the-uk-cost-of-living-affecting-your-ability-to-attend-weddings"
Url8 ="https://www.theguardian.com/football/2023/apr/30/fulham-wolves-english-clubs-cost-of-living-crisis-fans-season-tickets"
Url9 ="https://www.theguardian.com/business/2023/apr/14/shoppers-in-great-britain-switch-to-frozen-food-amid-cost-of-living-crisis"
Url10 ="https://www.theguardian.com/uk-news/2023/apr/09/cost-of-living-crisis-increase-problem-gambling-uk-gamcare"

#Get articles text
Text1 = GetText(Url1)
Text2 = GetText(Url2)
Text3 = GetText(Url3)
Text4 = GetText(Url4)
Text5 = GetText(Url5)
Text6 = GetText(Url6)
Text7 = GetText(Url7)
Text8 = GetText(Url8)
Text9 = GetText(Url9)
Text10=GetText(Url10)

# %%
len(Text1)
# Out:
# 3055

# %%
len(Text1.split())
# Out:
# 453

# %%
sentences= nltk.sent_tokenize(Text1)
len(sentences)
# Out:
# 9

# %%
len(Text2)
# Out:
# 6286

# %%
len(Text2.split())
# Out:
# 959

# %%
sentences= nltk.sent_tokenize(Text2)
len(sentences)
# Out:
# 24

# %%
len(Text3)
# Out:
# 3490

# %%
len(Text3.split())
# Out:
# 537

# %%
sentences= nltk.sent_tokenize(Text3)
len(sentences)
# Out:
# 17

# %%
len(Text4)
# Out:
# 2683

# %%
len(Text4.split())
# Out:
# 458

# %%
sentences= nltk.sent_tokenize(Text4)
len(sentences)
# Out:
# 17

# %%
len(Text5)
# Out:
# 1164

# %%
len(Text5.split())
# Out:
# 192

# %%
sentences= nltk.sent_tokenize(Text5)
len(sentences)
# Out:
# 5

# %%
len(Text6)
# Out:
# 22375

# %%
len(Text6.split())
# Out:
# 3647

# %%
sentences= nltk.sent_tokenize(Text6)
len(sentences)
# Out:
# 35

# %%
len(Text7)
# Out:
# 1452

# %%
len(Text7.split())
# Out:
# 247

# %%
sentences= nltk.sent_tokenize(Text7)
len(sentences)
# Out:
# 6

# %%
len(Text8)
# Out:
# 5680

# %%
len(Text8.split())
# Out:
# 919

# %%
sentences= nltk.sent_tokenize(Text8)
len(sentences)
# Out:
# 35

# %%
len(Text9)
# Out:
# 2883

# %%
len(Text9.split())
# Out:
# 474

# %%
sentences= nltk.sent_tokenize(Text9)
len(sentences)
# Out:
# 9

# %%
len(Text10)
# Out:
# 3900

# %%
len(Text10.split())
# Out:
# 644

# %%
sentences= nltk.sent_tokenize(Text10)
len(sentences)
# Out:
# 8

# %%
words1=nltk.word_tokenize(Text1.lower())
words2=nltk.word_tokenize(Text2.lower())
words3=nltk.word_tokenize(Text3.lower())
words4=nltk.word_tokenize(Text4.lower())
words5=nltk.word_tokenize(Text5.lower())
words6=nltk.word_tokenize(Text6.lower())
words7=nltk.word_tokenize(Text7.lower())
words8=nltk.word_tokenize(Text8.lower())
words9=nltk.word_tokenize(Text9.lower())
words10=nltk.word_tokenize(Text10.lower())

# %%
words1=[word.lower() for word in words1 if word.isalpha()]
words2=[word.lower() for word in words2 if word.isalpha()]
words3=[word.lower() for word in words3 if word.isalpha()]
words4=[word.lower() for word in words4 if word.isalpha()]
words5=[word.lower() for word in words5 if word.isalpha()]
words6=[word.lower() for word in words6 if word.isalpha()]
words7=[word.lower() for word in words7 if word.isalpha()]
words8=[word.lower() for word in words8 if word.isalpha()]
words9=[word.lower() for word in words9 if word.isalpha()]
words10=[word.lower() for word in words10 if word.isalpha()]

# %%
nltk.download('stopwords')
filtered_sentence1=[]
filtered_sentence2=[]
filtered_sentence3=[]
filtered_sentence4=[]
filtered_sentence5=[]
filtered_sentence6=[]
filtered_sentence7=[]
filtered_sentence8=[]
filtered_sentence9=[]
filtered_sentence10=[]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))

for w in words1:
  if w not in stop_words:
    filtered_sentence1.append(w)

# %%
import nltk
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))

for w in words2:
  if w not in stop_words:
    filtered_sentence2.append(w)

# %%
import nltk
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))

for w in words3:
  if w not in stop_words:
    filtered_sentence3.append(w)

# %%
import nltk
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))

for w in words4:
  if w not in stop_words:
    filtered_sentence4.append(w)

# %%
import nltk
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))

for w in words5:
  if w not in stop_words:
    filtered_sentence5.append(w)

# %%
import nltk
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))

for w in words6:
  if w not in stop_words:
    filtered_sentence6.append(w)

# %%
import nltk
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))

for w in words7:
  if w not in stop_words:
    filtered_sentence7.append(w)

# %%
import nltk
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))

for w in words8:
  if w not in stop_words:
    filtered_sentence8.append(w)

# %%
import nltk
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))

for w in words9:
  if w not in stop_words:
    filtered_sentence9.append(w)

# %%
import nltk
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))

for w in words10:
  if w not in stop_words:
    filtered_sentence10.append(w)

# %%
nltk.download('wordnet')

nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.stem import PorterStemmer,WordNetLemmatizer
from nltk.corpus import wordnet

ps = PorterStemmer()

stemmed_words1=[]
stemmed_words2=[]
stemmed_words3=[]
stemmed_words4=[]
stemmed_words5=[]
stemmed_words6=[]
stemmed_words7=[]
stemmed_words8=[]
stemmed_words9=[]
stemmed_words10=[]

# %%
for w in filtered_sentence1:
  rootword=ps.stem(w)
  stemmed_words1.append(rootword)

# %%
for w in filtered_sentence2:
  rootword=ps.stem(w)
  stemmed_words2.append(rootword)

# %%
for w in filtered_sentence3:
  rootword=ps.stem(w)
  stemmed_words3.append(rootword)

# %%
for w in filtered_sentence4:
  rootword=ps.stem(w)
  stemmed_words4.append(rootword)

# %%
for w in filtered_sentence5:
  rootword=ps.stem(w)
  stemmed_words5.append(rootword)

# %%
for w in filtered_sentence6:
  rootword=ps.stem(w)
  stemmed_words6.append(rootword)

# %%
for w in filtered_sentence7:
  rootword=ps.stem(w)
  stemmed_words7.append(rootword)

# %%
for w in filtered_sentence8:
  rootword=ps.stem(w)
  stemmed_words8.append(rootword)

# %%
for w in filtered_sentence9:
  rootword=ps.stem(w)
  stemmed_words9.append(rootword)

# %%
for w in filtered_sentence10:
  rootword=ps.stem(w)
  stemmed_words10.append(rootword)

# %%
print(stemmed_words7)
# Out:
# ['would', 'like', 'hear', 'guest', 'approach', 'wed', 'season', 'particularli', 'ceremoni', 'abroad', 'amid', 'uk', 'cost', 'live', 'crisiswed', 'season', 'fast', 'approach', 'even', 'guest', 'cost', 'stag', 'hen', 'do', 'gift', 'big', 'day', 'quickli', 'stack', 'money', 'tight', 'mani', 'uk', 'want', 'hear', 'navig', 'wed', 'season', 'particularli', 'invit', 'sever', 'event', 'space', 'invit', 'friend', 'wed', 'abroad', 'struggl', 'afford', 'involv', 'plan', 'hen', 'stag', 'weekend', 'spiral', 'cost', 'step', 'taken', 'cost', 'live', 'crisi', 'borrow', 'money', 'decid', 'attend', 'fewer', 'event', 'abl', 'cope', 'cost', 'would', 'like', 'speak', 'peopl', 'uk', 'approach', 'handl', 'cost', 'attend', 'wed', 'amid', 'cost', 'live', 'crisisinclud', 'much', 'detail', 'possibleinclud', 'much', 'detail', 'possibleyour', 'contact', 'detail', 'help', 'contact', 'inform', 'seen', 'contact', 'detail', 'help', 'contact', 'inform', 'seen', 'includ', 'peopl', 'name', 'pleas', 'ask', 'us', 'whatsa
# ...

# %%
frequency_dist1 = nltk.FreqDist(stemmed_words1)
frequency_dist2 = nltk.FreqDist(stemmed_words2)
frequency_dist3 = nltk.FreqDist(stemmed_words3)
frequency_dist4 = nltk.FreqDist(stemmed_words4)
frequency_dist5 = nltk.FreqDist(stemmed_words5)
frequency_dist6 = nltk.FreqDist(stemmed_words6)
frequency_dist7 = nltk.FreqDist(stemmed_words7)
frequency_dist8 = nltk.FreqDist(stemmed_words8)
frequency_dist9 = nltk.FreqDist(stemmed_words9)
frequency_dist10 = nltk.FreqDist(stemmed_words10)

# %%
sorted(frequency_dist7,key=frequency_dist1.__getitem__,reverse = True)[0:30]
# Out:
# ['uk',
#  'event',
#  'cost',
#  'inform',
#  'amid',
#  'peopl',
#  'help',
#  'day',
#  'struggl',
#  'weekend',
#  'crisi',
#  'borrow',
#  'see',
#  'via',
#  'contact',
#  'wed',
#  'detail',
#  'approach',
#  'season',
#  'live',
#  'pleas',
#  'would',
#  'like',
#  'hear',
#  'guest',
#  'particularli',
#  'abroad',
#  'stag',
#  'hen',
#  'money']

# %%
print(frequency_dist1)
# Out:
# <FreqDist with 192 samples and 270 outcomes>

# %%
large_words1 = dict([(k,v) for k,v in frequency_dist1.items() if len(k)>3])
large_words2 = dict([(k,v) for k,v in frequency_dist2.items() if len(k)>3])
large_words3 = dict([(k,v) for k,v in frequency_dist3.items() if len(k)>3])
large_words4 = dict([(k,v) for k,v in frequency_dist4.items() if len(k)>3])
large_words5 = dict([(k,v) for k,v in frequency_dist5.items() if len(k)>3])
large_words6 = dict([(k,v) for k,v in frequency_dist6.items() if len(k)>3])
large_words7 = dict([(k,v) for k,v in frequency_dist7.items() if len(k)>3])
large_words8 = dict([(k,v) for k,v in frequency_dist8.items() if len(k)>3])
large_words9 = dict([(k,v) for k,v in frequency_dist9.items() if len(k)>3])
large_words10 = dict([(k,v) for k,v in frequency_dist10.items() if len(k)>3])

# %%
print(large_words2)
# Out:
# {'lusaka': 3, 'april': 1, 'reuter': 7, 'comesa': 1, 'market': 6, 'zambia': 9, 'capit': 1, 'appear': 1, 'bustl': 1, 'trader': 2, 'busi': 6, 'suffer': 1, 'weak': 2, 'local': 3, 'currenc': 3, 'push': 1, 'price': 1, 'hardship': 1, 'popul': 1, 'alreadi': 1, 'struggl': 3, 'soar': 1, 'live': 2, 'cost': 3, 'dollar': 3, 'kill': 2, 'said': 7, 'mwandila': 1, 'sold': 1, 'import': 3, 'blanket': 1, 'month': 4, 'last': 1, 'year': 4, 'kwacha': 9, 'profit': 1, 'sale': 1, 'sell': 1, 'stop': 1, 'inflat': 1, 'fall': 1, 'recent': 4, 'offici': 3, 'economist': 2, 'blame': 2, 'part': 1, 'complet': 2, 'debt': 10, 'restructur': 4, 'sinc': 2, 'default': 1, 'well': 1, 'disappoint': 1, 'copper': 2, 'output': 1, 'bondhold': 2, 'invest': 3, 'whose': 3, 'bond': 1, 'matur': 1, 'money': 2, 'reinvest': 1, 'natali': 1, 'mwila': 1, 'centr': 2, 'trade': 1, 'polici': 1, 'develop': 1, 'zambian': 3, 'pressur': 1, 'obvious': 1, 'also': 2, 'rais': 1, 'strengthen': 1, 'juli': 1, 'presid': 1, 'hakaind': 1, 'hichilema': 1, 'took
# ...

# %%
frequency_dist1.plot(30,cumulative=False)
frequency_dist2.plot(30,cumulative=False)
frequency_dist3.plot(30,cumulative=False)
frequency_dist4.plot(30,cumulative=False)
frequency_dist5.plot(30,cumulative=False)
frequency_dist6.plot(30,cumulative=False)
frequency_dist7.plot(30,cumulative=False)
frequency_dist8.plot(30,cumulative=False)
frequency_dist9.plot(30,cumulative=False)
frequency_dist10.plot(30,cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
import matplotlib.pyplot as plt
import wordcloud as WordCloud
import nltk

# %%
from wordcloud.wordcloud import WordCloud
wordcloud= WordCloud(max_font_size=50,max_words=100,background_color='black').generate_from_frequencies(large_words1)
plt.figure()
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from wordcloud.wordcloud import WordCloud
wordcloud= WordCloud(max_font_size=50,max_words=100,background_color='black').generate_from_frequencies(large_words2)
plt.figure()
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from wordcloud.wordcloud import WordCloud
wordcloud= WordCloud(max_font_size=50,max_words=100,background_color='black').generate_from_frequencies(large_words2)
plt.figure()
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from wordcloud.wordcloud import WordCloud
wordcloud= WordCloud(max_font_size=50,max_words=100,background_color='black').generate_from_frequencies(large_words3)
plt.figure()
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from wordcloud.wordcloud import WordCloud
wordcloud= WordCloud(max_font_size=50,max_words=100,background_color='black').generate_from_frequencies(large_words4)
plt.figure()
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from wordcloud.wordcloud import WordCloud
wordcloud= WordCloud(max_font_size=50,max_words=100,background_color='black').generate_from_frequencies(large_words5)
plt.figure()
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from wordcloud.wordcloud import WordCloud
wordcloud= WordCloud(max_font_size=50,max_words=100,background_color='black').generate_from_frequencies(large_words6)
plt.figure()
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from wordcloud.wordcloud import WordCloud
wordcloud= WordCloud(max_font_size=50,max_words=100,background_color='black').generate_from_frequencies(large_words7)
plt.figure()
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from wordcloud.wordcloud import WordCloud
wordcloud= WordCloud(max_font_size=50,max_words=100,background_color='black').generate_from_frequencies(large_words8)
plt.figure()
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from wordcloud.wordcloud import WordCloud
wordcloud= WordCloud(max_font_size=50,max_words=100,background_color='black').generate_from_frequencies(large_words9)
plt.figure()
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from wordcloud.wordcloud import WordCloud
wordcloud= WordCloud(max_font_size=50,max_words=100,background_color='black').generate_from_frequencies(large_words10)
plt.figure()
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
